# %%
import pandas as pd
df=pd.read_csv("D:\\Study\\stack-overflow-developer-survey-2022\\survey_results_public.csv")
schema_df=pd.read_csv("D:\\Study\\stack-overflow-developer-survey-2022\\survey_results_schema.csv")

# %%
pd.set_option('display.max_rows',85)
pd.set_option('display.max_columns',85)

# %%
# !pip install pandas-profiling

# %%
from pandas_profiling import ProfileReport
prof= ProfileReport(df)
prof.to_file(output_file="output.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 3>()
#       1 from pandas_profiling import ProfileReport
#       2 prof= ProfileReport(df)
# ----> 3 prof.to_file(output_file="output.html")
#
# File ~\anaconda3\lib\site-packages\pandas_profiling\profile_report.py:277, in ProfileReport.to_file(self, output_file, silent)
#     274         self.config.html.assets_prefix = str(output_file.stem) + "_assets"
#     275     create_html_assets(self.config, output_file)
# --> 277 data = self.to_html()
#     279 if output_file.suffix != ".html":
#     280     suffix = output_file.suffix
#
# File ~\anaconda3\lib\site-packages\pandas_profiling\profile_report.py:388, in ProfileReport.to_html(self)
#     380 def to_html(self) -> str:
#     381     """Generate and return complete template as lengthy string
# ...

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
schema_df.head(85)
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2     QID1                    S1
# 3     QID2            MainBranch
# 4   QID296            Employment
# 5   QID308            RemoteWork
# 6   QID297      CodingActivities
# 7   QID190                    S2
# 8    QID25               EdLevel
# 9   QID276             LearnCode
# 10  QID281       LearnCodeOnline
# 11  QID306  LearnCodeCoursesCert
# 12   QID32             YearsCode
# 13   QID34          YearsCodePro
# 14   QID31               DevType
# 15   QID29               OrgSize
# 16  QID278     PurchaseInfluence
# 17  QID279            BuyNewTool
# 18    QID6               Country
# 19   QID50              Currency
# 20   QID51             CompTotal
# 21   QID52              CompFreq
# 22   QID61                    S3
# 23  QID233              Language
# 24  QID262              Database
# 25  QID263              Platform
# 26  QID264              Webframe
# ...

# %%
df['LanguageHaveWorkedWith'].value_counts()
# Out:
# HTML/CSS;JavaScript;TypeScript                                                              1250
# Python                                                                                       962
# HTML/CSS;JavaScript                                                                          914
# HTML/CSS;JavaScript;PHP;SQL                                                                  745
# C#;HTML/CSS;JavaScript;SQL;TypeScript                                                        570
#                                                                                             ...
# C#;Java;JavaScript;PHP;PowerShell;SQL;TypeScript                                               1
# C++;HTML/CSS;JavaScript;Python;Solidity;SQL                                                    1
# Dart;Haskell;HTML/CSS;Java;R;SQL;TypeScript                                                    1
# Bash/Shell;C;C#;Go;HTML/CSS;Java;JavaScript;Lua;Perl;PHP;Python;Ruby;Rust;SQL;TypeScript       1
# ...

# %%
df['Country'].value_counts(normalize=True)
# Out:
# United States of America                                0.188697
# India                                                   0.092503
# Germany                                                 0.075170
# United Kingdom of Great Britain and Northern Ireland    0.058380
# Canada                                                  0.034694
#                                                           ...
# Monaco                                                  0.000014
# Djibouti                                                0.000014
# Seychelles                                              0.000014
# Solomon Islands                                         0.000014
# Saint Kitts and Nevis                                   0.000014
# Name: Country, Length: 180, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Monaco                                                      1
# Djibouti                                                    1
# Seychelles                                                  1
# Solomon Islands                                             1
# Saint Kitts and Nevis                                       1
# Name: Country, Length: 180, dtype: int64

# %%
country_Group=df.groupby(['Country'])

# %%
country_Group.get_group('India')
# Out:
#        ResponseId                                         MainBranch  \
# 6               7                        I code primarily as a hobby
# 7               8                     I am a developer by profession
# 65             66                     I am a developer by profession
# 140           141                     I am a developer by profession
# 151           152                     I am a developer by profession
# ...           ...                                                ...
# 73184       73185                     I am a developer by profession
# 73193       73194  I used to be a developer by profession, but no...
# 73255       73256                     I am a developer by profession
# 73257       73258                              I am learning to code
# 73258       73259                     I am a developer by profession
#
#                                Employment  \
# 6                      Student, part-time
# 7      Not employed, but looking for work
# ...

# %%
filt=df['Country']=='India'
df.loc[filt][['LearnCodeCoursesCert','LanguageHaveWorkedWith']].value_counts()
# Out:
# LearnCodeCoursesCert        LanguageHaveWorkedWith
# Udemy                       HTML/CSS;JavaScript                                                                33
#                             HTML/CSS;JavaScript;TypeScript                                                     33
#                             JavaScript                                                                         28
#                             HTML/CSS;JavaScript;PHP                                                            21
#                             Java                                                                               19
#                                                                                                                ..
# Coursera;Udemy;Pluralsight  Bash/Shell;C;Java;Kotlin;Python;SQL                                                 1
#                             Bash/Shell;Elixir;Erlang;Go;HTML/CSS;Java;JavaScript;Python;Ruby;SQL;TypeScript     1
# ...

# %%
country_Group['LanguageHaveWorkedWith'].value_counts().loc['India']
# Out:
# LanguageHaveWorkedWith
# HTML/CSS;JavaScript               186
# HTML/CSS;JavaScript;TypeScript    182
# Python                            153
# Java                              118
# HTML/CSS;JavaScript;PHP;SQL        93
#                                  ...
# Rust;TypeScript                     1
# SQL;Swift                           1
# SQL;TypeScript                      1
# Scala                               1
# Solidity;Swift                      1
# Name: LanguageHaveWorkedWith, Length: 2818, dtype: int64

# %%
country_Group['ConvertedCompYearly'].value_counts().loc['India']
# Out:
# ConvertedCompYearly
# 38692.0      51
# 25794.0      49
# 12897.0      45
# 15477.0      45
# 19346.0      43
#              ..
# 1857204.0     1
# 2000000.0     1
# 2100000.0     1
# 4500000.0     1
# 6577582.0     1
# Name: ConvertedCompYearly, Length: 566, dtype: int64

# %%
country_Group['ConvertedCompYearly'].agg(['median','mean']).loc['India']
# Out:
# median    18576.000000
# mean      51443.079613
# Name: India, dtype: float64

# %%
filt=df['Country']=='India'
df.loc[filt][['LearnCodeCoursesCert','LanguageHaveWorkedWith']].value_counts()
# Out:
# LearnCodeCoursesCert        LanguageHaveWorkedWith
# Udemy                       HTML/CSS;JavaScript                                                                33
#                             HTML/CSS;JavaScript;TypeScript                                                     33
#                             JavaScript                                                                         28
#                             HTML/CSS;JavaScript;PHP                                                            21
#                             Java                                                                               19
#                                                                                                                ..
# Coursera;Udemy;Pluralsight  Bash/Shell;C;Java;Kotlin;Python;SQL                                                 1
#                             Bash/Shell;Elixir;Erlang;Go;HTML/CSS;Java;JavaScript;Python;Ruby;SQL;TypeScript     1
# ...

# %%
filt=df['Country']=='India'
df.loc[filt]['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# 3081

# %%
filt=df['Country']=='India'
country_Group['LanguageHaveWorkedWith'].apply(lambda x:x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              25
# Albania                                  19
# Algeria                                  19
# Andorra                                   4
# Angola                                    3
#                                        ...
# Venezuela, Bolivarian Republic of...     52
# Viet Nam                                136
# Yemen                                     4
# Zambia                                    6
# Zimbabwe                                 11
# Name: LanguageHaveWorkedWith, Length: 180, dtype: int64

# %%
couuntry_USES_PYTHON=country_Group['LanguageHaveWorkedWith'].apply(lambda x:x.str.contains('Python').sum())
couuntry_USES_PYTHON
# Out:
# Country
# Afghanistan                              25
# Albania                                  19
# Algeria                                  19
# Andorra                                   4
# Angola                                    3
#                                        ...
# Venezuela, Bolivarian Republic of...     52
# Viet Nam                                136
# Yemen                                     4
# Zambia                                    6
# Zimbabwe                                 11
# Name: LanguageHaveWorkedWith, Length: 180, dtype: int64

# %%
couuntry_USES_PYTHON['India']
# Out:
# 3081

# %%
python_df=pd.concat([couuntry_USES_PYTHON], axis='columns', sort=False)
python_df
# Out:
#                                       LanguageHaveWorkedWith
# Country
# Afghanistan                                               25
# Albania                                                   19
# Algeria                                                   19
# Andorra                                                    4
# Angola                                                     3
# ...                                                      ...
# Venezuela, Bolivarian Republic of...                      52
# Viet Nam                                                 136
# Yemen                                                      4
# Zambia                                                     6
# Zimbabwe                                                  11
#
# [180 rows x 1 columns]

# %%
df.groupby('Employment')[['Country','ConvertedCompYearly']].mean()
# Out:
#                                                     ConvertedCompYearly
# Employment
# Employed, full-time                                       173840.038410
# Employed, full-time;Employed, part-time                    85164.980392
# Employed, full-time;Independent contractor, fre...        155606.071266
# Employed, full-time;Independent contractor, fre...         86016.134454
# Employed, full-time;Independent contractor, fre...                  NaN
# ...                                                                 ...
# Student, part-time;Not employed, but looking fo...                  NaN
# Student, part-time;Not employed, but looking fo...                  NaN
# Student, part-time;Not employed, but looking fo...                  NaN
# Student, part-time;Not employed, but looking fo...                  NaN
# Student, part-time;Retired                                          NaN
#
# [103 rows x 1 columns]

# %%
df.iloc[[1,2,3,4],[0,1,2,3]]
# Out:
#    ResponseId                                         MainBranch  \
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)

# %%
df.iloc[25:60,:]
# Out:
#     ResponseId                                         MainBranch  \
# 25          26                     I am a developer by profession
# 26          27                     I am a developer by profession
# 27          28                     I am a developer by profession
# 28          29                     I am a developer by profession
# 29          30                     I am a developer by profession
# 30          31                                      None of these
# 31          32                     I am a developer by profession
# 32          33                        I code primarily as a hobby
# 33          34  I am not primarily a developer, but I write co...
# 34          35                     I am a developer by profession
# 35          36  I am not primarily a developer, but I write co...
# 36          37                     I am a developer by profession
# 37          38                     I am a developer by profession
# ...

# %%
df['LearnCodeCoursesCert']
# Out:
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#                        ...
# 73263                               Udemy
# 73264              Coursera;Udemy;Udacity
# 73265    Udemy;Codecademy;Pluralsight;edX
# 73266                                 NaN
# 73267                   Udemy;Pluralsight
# Name: LearnCodeCoursesCert, Length: 73268, dtype: object

# %%
df['LearnCodeCoursesCert'].value_counts()
# Out:
# Udemy                                     5643
# Other                                     2594
# Coursera;Udemy                            1893
# Udemy;Codecademy                          1472
# Udemy;Pluralsight                         1402
#                                           ...
# Udemy;Codecademy;edX;Udacity;Skillsoft       1
# Coursera;Other;Skillsoft                     1
# Codecademy;edX;Udacity;Skillsoft             1
# Pluralsight;edX;Udacity;Other                1
# Coursera;Pluralsight;Other;Skillsoft         1
# Name: LearnCodeCoursesCert, Length: 206, dtype: int64

# %%
df['LearnCodeCoursesCert'].value_counts(normalize=True)
# Out:
# Udemy                                     0.192011
# Other                                     0.088264
# Coursera;Udemy                            0.064412
# Udemy;Codecademy                          0.050087
# Udemy;Pluralsight                         0.047705
#                                             ...
# Udemy;Codecademy;edX;Udacity;Skillsoft    0.000034
# Coursera;Other;Skillsoft                  0.000034
# Codecademy;edX;Udacity;Skillsoft          0.000034
# Pluralsight;edX;Udacity;Other             0.000034
# Coursera;Pluralsight;Other;Skillsoft      0.000034
# Name: LearnCodeCoursesCert, Length: 206, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Monaco                                                      1
# Djibouti                                                    1
# Seychelles                                                  1
# Solomon Islands                                             1
# Saint Kitts and Nevis                                       1
# Name: Country, Length: 180, dtype: int64

# %%
Continet=df.groupby(['Ethnicity'])

# %%
Continet.get_group('Asian')
# Out:
#        ResponseId                                         MainBranch  \
# 58             59                     I am a developer by profession
# 171           172                     I am a developer by profession
# 175           176  I used to be a developer by profession, but no...
# 209           210  I used to be a developer by profession, but no...
# 301           302                     I am a developer by profession
# ...           ...                                                ...
# 73237       73238                     I am a developer by profession
# 73244       73245                     I am a developer by profession
# 73252       73253                              I am learning to code
# 73253       73254                     I am a developer by profession
# 73258       73259                     I am a developer by profession
#
#                                Employment  \
# 58                    Employed, full-time
# 171                   Employed, full-time
# ...

# %%
Asian_filt=df['Ethnicity']=='Asian'
df.loc[Asian_filt]
# Out:
#        ResponseId                                         MainBranch  \
# 58             59                     I am a developer by profession
# 171           172                     I am a developer by profession
# 175           176  I used to be a developer by profession, but no...
# 209           210  I used to be a developer by profession, but no...
# 301           302                     I am a developer by profession
# ...           ...                                                ...
# 73237       73238                     I am a developer by profession
# 73244       73245                     I am a developer by profession
# 73252       73253                              I am learning to code
# 73253       73254                     I am a developer by profession
# 73258       73259                     I am a developer by profession
#
#                                Employment  \
# 58                    Employed, full-time
# 171                   Employed, full-time
# ...

# %%
df.loc[Asian_filt]['Country'].value_counts()
# Out:
# India                                                   546
# United States of America                                435
# China                                                   291
# Pakistan                                                286
# Bangladesh                                              183
# Indonesia                                               143
# Taiwan                                                  121
# Philippines                                             113
# Viet Nam                                                101
# Canada                                                   98
# South Korea                                              94
# Sri Lanka                                                91
# Iran, Islamic Republic of...                             90
# Australia                                                76
# Hong Kong (S.A.R.)                                       68
# Japan                                                    64
# ...

# %%
df['Country'].value_counts()
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Monaco                                                      1
# Djibouti                                                    1
# Seychelles                                                  1
# Solomon Islands                                             1
# Saint Kitts and Nevis                                       1
# Name: Country, Length: 180, dtype: int64

# %%
Country_groupby=df.groupby(['Country'])

# %%
filt_Country=df['Country']=='India'

# %%
df.loc[filt_Country]['Employment'].value_counts(normalize=True)
# Out:
# Employed, full-time                                                                                                                                                                                             0.586825
# Student, full-time                                                                                                                                                                                              0.145312
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                                                                                                        0.043563
# Independent contractor, freelancer, or self-employed                                                                                                                                                            0.039192
# ...

# %%
Country_groupby['LanguageHaveWorkedWith'].value_counts().loc['India'].loc['Python']
# Out:
# 153

# %%
Country_groupby['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum()).loc['India']
# Out:
# 3081

# %%
Country_USES_PYTHON=Country_groupby['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
Country_USES_PYTHON
# Out:
# Country
# Afghanistan                              25
# Albania                                  19
# Algeria                                  19
# Andorra                                   4
# Angola                                    3
#                                        ...
# Venezuela, Bolivarian Republic of...     52
# Viet Nam                                136
# Yemen                                     4
# Zambia                                    6
# Zimbabwe                                 11
# Name: LanguageHaveWorkedWith, Length: 180, dtype: int64

# %%
Country_USES_PYTHON['Viet Nam']
# Out:
# 136

# %%
python_df
# Out:
#                                       LanguageHaveWorkedWith
# Country
# Afghanistan                                               25
# Albania                                                   19
# Algeria                                                   19
# Andorra                                                    4
# Angola                                                     3
# ...                                                      ...
# Venezuela, Bolivarian Republic of...                      52
# Viet Nam                                                 136
# Yemen                                                      4
# Zambia                                                     6
# Zimbabwe                                                  11
#
# [180 rows x 1 columns]
