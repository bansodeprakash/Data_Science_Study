# %%
import pandas as pd

# %%
#df= data frame data of rows and colums

df=pd.read_csv("D:\\Study\\stack-overflow-developer-survey-2022\\survey_results_public.csv")
schema_df=pd.read_csv("D:\\Study\\stack-overflow-developer-survey-2022\\survey_results_schema.csv")
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# ...

# %%
schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2     QID1           S1  <span style="font-size:22px; font-family: aria...
# 3     QID2   MainBranch  Which of the following options best describes ...
# 4   QID296   Employment  Which of the following best describes your cur...
# ..     ...          ...                                                ...
# 74  QID290  Frequency_2  Interacting with people outside of your immedi...
# 75  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
# 76  QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  QID294  TrueFalse_2  Do you use learning resources provided by your...
# 78  QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#    force_resp  type selector
# 0       False    DB       TB
# ...

# %%
df.tail()
# Out:
#        ResponseId                                         MainBranch  \
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# ...

# %%
df[['Employment','RemoteWork']]
# Out:
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork
# 0                                       NaN
# 1                              Fully remote
# 2      Hybrid (some remote, some in-person)
# 3                              Fully remote
# 4      Hybrid (some remote, some in-person)
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df.iloc[1]
# Out:
# ResponseId                                                    2
# MainBranch                       I am a developer by profession
# Employment                                  Employed, full-time
# RemoteWork                                         Fully remote
# CodingActivities       Hobby;Contribute to open-source projects
#                                          ...
# TrueFalse_2                                                 NaN
# TrueFalse_3                                                 NaN
# SurveyLength                                           Too long
# SurveyEase                                            Difficult
# ConvertedCompYearly                                         NaN
# Name: 1, Length: 79, dtype: object

# %%
df.loc[0]
# Out:
# ResponseId                         1
# MainBranch             None of these
# Employment                       NaN
# RemoteWork                       NaN
# CodingActivities                 NaN
#                            ...
# TrueFalse_2                      NaN
# TrueFalse_3                      NaN
# SurveyLength                     NaN
# SurveyEase                       NaN
# ConvertedCompYearly              NaN
# Name: 0, Length: 79, dtype: object

# %%
df.shape
# Out:
# (73268, 79)

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df['CodingActivities'].value_counts()
# Out:
# Hobby                                                                                                                                  18118
# I don’t code outside of work                                                                                                            7311
# Hobby;Contribute to open-source projects                                                                                                6549
# Hobby;Freelance/contract work                                                                                                           3554
# Hobby;School or academic work                                                                                                           3016
#                                                                                                                                        ...
# Contribute to open-source projects;Freelance/contract work;Other (please specify):;School or academic work                                 2
# ...

# %%
df.loc[:10,'LanguageHaveWorkedWith']
# Out:
# 0                                                  NaN
# 1                                JavaScript;TypeScript
# 2                    C#;C++;HTML/CSS;JavaScript;Python
# 3                         C#;JavaScript;SQL;TypeScript
# 4          C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
# 5                                              C++;Lua
# 6        C++;HTML/CSS;JavaScript;PHP;Python;TypeScript
# 7                   C;C++;HTML/CSS;Java;JavaScript;SQL
# 8                                                  NaN
# 9                                    Delphi;Java;Swift
# 10    Bash/Shell;C#;HTML/CSS;JavaScript;PowerShell;SQL
# Name: LanguageHaveWorkedWith, dtype: object

# %%
df.loc[0]
# Out:
# ResponseId                         1
# MainBranch             None of these
# Employment                       NaN
# RemoteWork                       NaN
# CodingActivities                 NaN
#                            ...
# TrueFalse_2                      NaN
# TrueFalse_3                      NaN
# SurveyLength                     NaN
# SurveyEase                       NaN
# ConvertedCompYearly              NaN
# Name: 0, Length: 79, dtype: object

# %%
df.set_index('LanguageHaveWorkedWith')
# Out:
#                                                     ResponseId  \
# LanguageHaveWorkedWith
# NaN                                                          1
# JavaScript;TypeScript                                        2
# C#;C++;HTML/CSS;JavaScript;Python                            3
# C#;JavaScript;SQL;TypeScript                                 4
# C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript                  5
# ...                                                        ...
# Bash/Shell;Dart;JavaScript;PHP;Python;SQL;TypeS...       73264
# Bash/Shell;HTML/CSS;JavaScript;Python;SQL                73265
# HTML/CSS;JavaScript;PHP;Python;SQL                       73266
# C#;Delphi;VBA                                            73267
# C#;JavaScript;Lua;PowerShell;SQL;TypeScript              73268
#
#                                                                                            MainBranch  \
# LanguageHaveWorkedWith
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=73268, step=1)

# %%
df.loc[1]
# Out:
# ResponseId                                                    2
# MainBranch                       I am a developer by profession
# Employment                                  Employed, full-time
# RemoteWork                                         Fully remote
# CodingActivities       Hobby;Contribute to open-source projects
#                                          ...
# TrueFalse_2                                                 NaN
# TrueFalse_3                                                 NaN
# SurveyLength                                           Too long
# SurveyEase                                            Difficult
# ConvertedCompYearly                                         NaN
# Name: 1, Length: 79, dtype: object

# %%
df['Employment']=='Employed, full-time'
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 73263     True
# 73264     True
# 73265     True
# 73266     True
# 73267    False
# Name: Employment, Length: 73268, dtype: bool

# %%
fulltimework=(df['Employment']=='Employed, full-time' ) & (df['CodingActivities']=='Hobby')
df[fulltimework]
# Out:
#        ResponseId                                         MainBranch  \
# 2               3  I am not primarily a developer, but I write co...
# 4               5                     I am a developer by profession
# 12             13                     I am a developer by profession
# 16             17                     I am a developer by profession
# 17             18                     I am a developer by profession
# ...           ...                                                ...
# 73254       73255  I am not primarily a developer, but I write co...
# 73258       73259                     I am a developer by profession
# 73261       73262                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73266       73267                     I am a developer by profession
#
#                 Employment                            RemoteWork  \
# 2      Employed, full-time  Hybrid (some remote, some in-person)
# ...

# %%
df.loc[fulltimework,'EdLevel']
# Out:
# 2        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 12          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 16          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 17       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#                               ...
# 73254    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73258       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73261    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73264    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73266       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Name: EdLevel, Length: 15897, dtype: object

# %%
Education=(df['Employment']=='Employed, full-time' ) | (df['CodingActivities']=='Hobby')
df[fulltimework]
# Out:
#        ResponseId                                         MainBranch  \
# 2               3  I am not primarily a developer, but I write co...
# 4               5                     I am a developer by profession
# 12             13                     I am a developer by profession
# 16             17                     I am a developer by profession
# 17             18                     I am a developer by profession
# ...           ...                                                ...
# 73254       73255  I am not primarily a developer, but I write co...
# 73258       73259                     I am a developer by profession
# 73261       73262                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73266       73267                     I am a developer by profession
#
#                 Employment                            RemoteWork  \
# 2      Employed, full-time  Hybrid (some remote, some in-person)
# ...

# %%
high_salary=(df['ConvertedCompYearly']>100000)

df.loc[high_salary,['Employment','LanguageHaveWorkedWith','ConvertedCompYearly']]
# Out:
#                                               Employment  \
# 3                                    Employed, full-time
# 11     Employed, full-time;Independent contractor, fr...
# 14     Employed, full-time;Independent contractor, fr...
# 17                                   Employed, full-time
# 26                                   Employed, full-time
# ...                                                  ...
# 73101                                Employed, full-time
# 73102                                Employed, full-time
# 73105                                Employed, full-time
# 73111                                Employed, full-time
# 73116                                Employed, full-time
#
#                                   LanguageHaveWorkedWith  ConvertedCompYearly
# 3                           C#;JavaScript;SQL;TypeScript             215232.0
# 11     C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL             194400.0
# ...

# %%
pyth=df['LanguageHaveWorkedWith'].str.contains('Python',na=False)
df.loc[pyth,'LanguageHaveWorkedWith']
# Out:
# 2                        C#;C++;HTML/CSS;JavaScript;Python
# 6            C++;HTML/CSS;JavaScript;PHP;Python;TypeScript
# 11       C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL
# 14             HTML/CSS;JavaScript;PHP;Python;R;Ruby;Scala
# 16                                    C#;Java;PHP;Python;R
#                                ...
# 73257                                         C;Python;SQL
# 73261    Bash/Shell;HTML/CSS;Java;JavaScript;Python;SQL...
# 73263    Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264            Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                   HTML/CSS;JavaScript;PHP;Python;SQL
# Name: LanguageHaveWorkedWith, Length: 34155, dtype: object

# %%
pyth
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 73263     True
# 73264     True
# 73265     True
# 73266    False
# 73267    False
# Name: LanguageHaveWorkedWith, Length: 73268, dtype: bool

# %%
df.rename(columns={'ConvertedCompYearly':'SalaryUSD'},inplace=True)
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# ...

# %%
df['hobbys']=df['CodingActivities'].str.contains('Hobby',na=False)
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# ...

# %%
df.drop(columns=['hobbys'], inplace=True)

df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# ...

# %%
df.append({'Onboarding':'Just right'},ignore_index=True,sort=False)
# Out:
# C:\Users\banso\AppData\Local\Temp\ipykernel_23360\1115506933.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append({'Onboarding':'Just right'},ignore_index=True,sort=False)
#        ResponseId                                         MainBranch  \
# 0             1.0                                      None of these
# 1             2.0                     I am a developer by profession
# 2             3.0  I am not primarily a developer, but I write co...
# 3             4.0                     I am a developer by profession
# 4             5.0                     I am a developer by profession
# ...           ...                                                ...
# 73264     73265.0                     I am a developer by profession
# 73265     73266.0  I am not primarily a developer, but I write co...
# 73266     73267.0                     I am a developer by profession
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [103], in <cell line: 1>()
# ----> 1 df.sort_values(by=['ConvertedCompYearly','ResponseId'],ascending=[False,False],inplace=True)
#       2 df
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:6295, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6290     raise ValueError(
# ...

# %%
df.sort_index()

# %%
df.sort_values(by=['EdLevel','ConvertedCompYearly'],ascending=[True,False],inplace=True)

# %%
df[['EdLevel','ConvertedCompYearly']].head(100)

# %%
df['ConvertedCompYearly'].nlargest(500)

# %%
df.nlargest(10,'ConvertedCompYearly')

# %%
df['ConvertedCompYearly'].head(15)

# %%
df['ConvertedCompYearly'].median()

# %%
df.median()

# %%
df.describe()

# %%
df['ConvertedCompYearly'].count()

# %%
df[]
